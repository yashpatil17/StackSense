# %%
from sklearn.metrics import hamming_loss
from sklearn.metrics import jaccard_score
from sklearn.metrics import precision_recall_fscore_support as score
from sklearn.metrics import precision_score, recall_score, f1_score
from sklearn.metrics import roc_curve, auc
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.preprocessing import MultiLabelBinarizer
from sklearn.model_selection import train_test_split
from sklearn.calibration import CalibratedClassifierCV
from sklearn.multioutput import MultiOutputClassifier
from sklearn import metrics
from sklearn.svm import LinearSVC
import transformers
from torch.utils.data import Dataset, DataLoader, RandomSampler, SequentialSampler
from transformers import BertTokenizer, BertModel, BertConfig
import seaborn as sns
import shutil, sys
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import warnings
import torch
import os

# %%
MAX_LEN = 256
TRAIN_BATCH_SIZE = 36
VALID_BATCH_SIZE = 36
EPOCHS = 5
LEARNING_RATE = 1e-05

tokenizer = BertTokenizer.from_pretrained('bert-base-uncased')

train_params = {'batch_size': TRAIN_BATCH_SIZE,
                'shuffle': True,
                'num_workers': 0
                }

test_params = {'batch_size': VALID_BATCH_SIZE,
                'shuffle': False,
                'num_workers': 0
                }

# %%
warnings.simplefilter("ignore")
sns.set_style("darkgrid")
pd.set_option('display.max_columns', None)
pd.set_option('display.max_colwidth', None)

# %%
# if torch.cuda.is_available():
#     device = torch.device("cuda")
#     print('There are %d GPU(s) available.' % torch.cuda.device_count())
#     print('We will use the GPU:', torch.cuda.get_device_name(0))

# else:
#     print('No GPU available, using the CPU instead.')
#     device = torch.device("cpu")

# %%
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# %%
device
# Out:
# device(type='cuda')

# %%
df = pd.read_pickle("./df_eda.pkl")
df['Combo'] = df['Title'] + ". " + df['Body']

# %%
mlb = MultiLabelBinarizer()
tag_df = pd.DataFrame(mlb.fit_transform(df['Tags']), columns=mlb.classes_, index=df.index)
class_names = mlb.classes_

# %%
df = df.join(tag_df)
df = df.drop(columns='Tags')
df['target_list'] = df.iloc[:, 3:103].values.tolist()
df = df.drop(df.columns[3:103], axis=1)
df = df.drop(df.columns[0:2], axis=1)

# %%
############################### SPLIT
# cross checking that my train and test split is exatcly the same with
# the train test split i did for the model A.
# reason for the check is the difference in data structures (df vs array)
# (for example pd.sample(random_state=0) returns different split than sklearn for the same state)

# so the split is 80/20 for train-val/test
# and another 80/20 for train/val
# so train: 72%, val 8%, and test 20%

# Splitting the dataframe
train_dataset, test_dataset = train_test_split(df, test_size=0.2, random_state=0)
train_dataset, val_dataset = train_test_split(train_dataset, test_size=0.2, random_state=0)

train_dataset = train_dataset.reset_index(drop=True)
val_dataset = val_dataset.reset_index(drop=True)
test_dataset = test_dataset.reset_index(drop=True)

# Xy_train, Xy_test = train_test_split(df, test_size = 0.2, random_state = 0)
# Xy_train, Xy_val = train_test_split(Xy_train, test_size = 0.1, random_state = 0)

# # Resetting the indices
# train_dataset = test_dataset.reset_index(drop=True)
# val_dataset = valid_dataset.reset_index(drop=True)


# DEBUG
# print(Xy_train.head(1))
# print(Xy_test.head(1))
# quit()

print("[PROGRAM]: full-set shape: {}".format(df.shape))
print("[PROGRAM]: train-set shape: {}".format(train_dataset.shape))
print("[PROGRAM]: val-set shape: {}".format(val_dataset.shape))
print("[PROGRAM]: test-set shape: {}".format(test_dataset.shape))
# Out:
# [PROGRAM]: full-set shape: (80393, 2)
# [PROGRAM]: train-set shape: (51451, 2)
# [PROGRAM]: val-set shape: (12863, 2)
# [PROGRAM]: test-set shape: (16079, 2)

# %%
class CustomDataset(Dataset):

    def __init__(self, dataframe, tokenizer, max_len):
        self.tokenizer = tokenizer
        self.data = dataframe
        self.combo = dataframe['Combo']
        self.targets = self.data.target_list
        self.max_len = max_len

    def __len__(self):
        return len(self.combo)

    def __getitem__(self, index):
        combo = str(self.combo[index])
        combo = " ".join(combo.split())

        inputs = self.tokenizer.encode_plus(
            combo,
            None,
            add_special_tokens=True,
            max_length=self.max_len,
            padding='max_length',
            return_token_type_ids=True,
            truncation=True
        )
        ids = inputs['input_ids']
        mask = inputs['attention_mask']
        token_type_ids = inputs["token_type_ids"]


        return {
            'ids': torch.tensor(ids, dtype=torch.long),
            'mask': torch.tensor(mask, dtype=torch.long),
            'token_type_ids': torch.tensor(token_type_ids, dtype=torch.long),
            'targets': torch.tensor(self.targets[index], dtype=torch.float)
        }


train_set = CustomDataset(train_dataset, tokenizer, MAX_LEN)
val_set = CustomDataset(val_dataset, tokenizer, MAX_LEN)
test_set = CustomDataset(test_dataset, tokenizer, MAX_LEN)

# DEBUG
# print(train_set[0])

# %%
############################### TORCH DATALOADER
training_loader = DataLoader(train_set, **train_params)
validation_loader = DataLoader(val_set, **test_params)
test_loader = DataLoader(test_set, **test_params)

len(training_loader)
# Out:
# 1430

# %%
def loss_fn(outputs, targets):
    return torch.nn.BCEWithLogitsLoss()(outputs, targets)

def load_ckp(checkpoint_fpath, model, optimizer):
    # load check point
    # initialize state_dict from checkpoint to model
    # initialize optimizer from checkpoint to optimizer
    # initialize valid_loss_min from checkpoint to valid_loss_min
    # return model, optimizer, epoch value, min validation loss

    checkpoint = torch.load(checkpoint_fpath)
    model.load_state_dict(checkpoint['state_dict'])
    optimizer.load_state_dict(checkpoint['optimizer'])
    valid_loss_min = checkpoint['valid_loss_min']
    return model, optimizer, checkpoint['epoch'], valid_loss_min

def save_ckp(state, is_best, checkpoint_path, best_model_path):
    # save checkpoint data to the path given, checkpoint_path
    # if it is a best model, min validation loss
    # copy that checkpoint file to best path given, best_model_path

    f_path = checkpoint_path
    torch.save(state, f_path)
    if is_best:
        best_fpath = best_model_path
        shutil.copyfile(f_path, best_fpath)

# %%
############################### MODEL
# base : bert
# extra dropout + linear layer
# ending in 100 neurons, just like our classes
# after i extract the propabillities of each of the 100 neurons
# i select the proba >0.5 and bin the results to (0,1) (like sigmoid but manual)

class BERTClass(torch.nn.Module):
    def __init__(self):
        super(BERTClass, self).__init__()
        self.l1 = transformers.BertModel.from_pretrained('bert-base-uncased', return_dict=False)
        self.l2 = torch.nn.Dropout(0.4)
        self.l3 = torch.nn.Linear(768, 100)

    def forward(self, ids, mask, token_type_ids):
        _, output_1= self.l1(ids, attention_mask = mask, token_type_ids = token_type_ids)
        output_2 = self.l2(output_1)
        output = self.l3(output_2)
        return output

model = BERTClass()
model = torch.nn.DataParallel(model)
model.to(device)
print("[INFO]: model loaded to device")
# Out:
# [INFO]: model loaded to device

# %%
############################### LOOP
# globals
val_targets=[]
val_outputs=[]
optimizer = torch.optim.Adam(params =  model.parameters(), lr=LEARNING_RATE)

print("[INFO]: starting training")
def train_model(start_epochs,  n_epochs, valid_loss_min_input,
                training_loader, validation_loader, model,
                optimizer, checkpoint_path, best_model_path):

    # initialize tracker for minimum validation loss
    valid_loss_min = valid_loss_min_input

    for epoch in range(start_epochs, n_epochs+1):
        train_loss = 0
        valid_loss = 0

        model.train()
        print('[PROGRAM]: epoch', epoch)
        print('[PROGRAM]: TRAINING START')
        for batch_idx, data in enumerate(training_loader):
            print('[PROGRAM]: TRAINING batch ', batch_idx, ' /1420')
            ids = data['ids'].to(device, dtype = torch.long)
            mask = data['mask'].to(device, dtype = torch.long)
            token_type_ids = data['token_type_ids'].to(device, dtype = torch.long)
            targets = data['targets'].to(device, dtype = torch.float)
            outputs = model(ids, mask, token_type_ids)
            optimizer.zero_grad()
            loss = loss_fn(outputs, targets)
            optimizer.zero_grad()
            loss.backward()
            optimizer.step()
            train_loss = train_loss + ((1 / (batch_idx + 1)) * (loss.item() - train_loss))

        model.eval()
        print('[PROGRAM]: epoch', epoch)
        print('[PROGRAM]: VALIDATION START')

        with torch.no_grad():
            for batch_idx, data in enumerate(validation_loader, 0):
                print('[PROGRAM]: VALIDATION batch ', batch_idx)
                ids = data['ids'].to(device, dtype = torch.long)
                mask = data['mask'].to(device, dtype = torch.long)
                token_type_ids = data['token_type_ids'].to(device, dtype = torch.long)
                targets = data['targets'].to(device, dtype = torch.float)
                outputs = model(ids, mask, token_type_ids)
                loss = loss_fn(outputs, targets)
                valid_loss = valid_loss + ((1 / (batch_idx + 1)) * (loss.item() - valid_loss))
                val_targets.extend(targets.cpu().detach().numpy().tolist())
                val_outputs.extend(torch.sigmoid(outputs).cpu().detach().numpy().tolist())

            print('[PROGRAM]: VALIDATION END')
            # calculate average losses
            train_loss = train_loss/len(training_loader)
            valid_loss = valid_loss/len(validation_loader)
            print('[PROGRAM]: Epoch: {} \tAvgerage Training Loss: {:.6f} \tAverage Validation Loss: {:.6f}'.format(
                epoch,
                train_loss,
                valid_loss
                ))

        # train_loss = train_loss/len(training_loader)
        
        print('[PROGRAM]: Epoch: {} \tAvgerage Training Loss: {:.6f}\tAvgerage Val Loss: {:.6f}'.format(
                epoch,
                train_loss,
                valid_loss
                ))

        # create checkpoint variable and add important data
        checkpoint = {
            'epoch': epoch + 1,
            'valid_loss_min': valid_loss,
            'state_dict': model.state_dict(),
            'optimizer': optimizer.state_dict()
        }

        # save checkpoint
        save_ckp(checkpoint, False, checkpoint_path, best_model_path)
        if valid_loss <= valid_loss_min:
            print('[PROGRAM]: Validation loss decreased ({:.6f} --> {:.6f}).  Saving model ...'.format(valid_loss_min,valid_loss))
            # save checkpoint as best model
            save_ckp(checkpoint, True, checkpoint_path, best_model_path)
            valid_loss_min = valid_loss
        
        print('[PROGRAM]: Epoch {}  Done \n'.format(epoch))


    return model
# Out:
# [INFO]: starting training

# %%
############################### DIRS
# check if the directory already exists
# if it does not exist, create the directory

directory_checkpoints = "./checkpoints"
directory_best_models = "./best_models"

if not os.path.exists(directory_checkpoints):
    os.makedirs(directory_checkpoints)
    print("Directory './checkpoints' created successfully.")
else:
    print("Directory '/checkpoints' already exists.")

if not os.path.exists(directory_best_models):
    os.makedirs(directory_best_models)
    print("Directory './best_models' created successfully.")
else:
    print("Directory './best_models' already exists.")

checkpoint_path = "./checkpoints/current_checkpoint.pt"
best_model = "./best_models/best_model.pt"
# Out:
# Directory '/checkpoints' already exists.
# Directory './best_models' already exists.

# %%
############################### RUN
trained_model = train_model(1, EPOCHS, np.Inf, training_loader, validation_loader, model,
                      optimizer, checkpoint_path, best_model)
# Out:
# [PROGRAM]: epoch 1
# [PROGRAM]: TRAINING START
# [PROGRAM]: TRAINING batch  0  /1420
# [PROGRAM]: TRAINING batch  1  /1420
# [PROGRAM]: TRAINING batch  2  /1420
# [PROGRAM]: TRAINING batch  3  /1420
# [PROGRAM]: TRAINING batch  4  /1420
# [PROGRAM]: TRAINING batch  5  /1420
# [PROGRAM]: TRAINING batch  6  /1420
# [PROGRAM]: TRAINING batch  7  /1420
# [PROGRAM]: TRAINING batch  8  /1420
# [PROGRAM]: TRAINING batch  9  /1420
# [PROGRAM]: TRAINING batch  10  /1420
# [PROGRAM]: TRAINING batch  11  /1420
# [PROGRAM]: TRAINING batch  12  /1420
# [PROGRAM]: TRAINING batch  13  /1420
# [PROGRAM]: TRAINING batch  14  /1420
# [PROGRAM]: TRAINING batch  15  /1420
# [PROGRAM]: TRAINING batch  16  /1420
# [PROGRAM]: TRAINING batch  17  /1420
# [PROGRAM]: TRAINING batch  18  /1420
# [PROGRAM]: TRAINING batch  19  /1420
# [PROGRAM]: TRAINING batch  20  /1420
# [PROGRAM]: TRAINING batch  21  /1420
# [PROGRAM]: TRAINING batch  22  /1420
# [PROGRAM]: TRAINING batch  23  /1420
# [PROGRAM]: TRAINING batch  24  /1420
# [PROGRAM]: TRAINING batch  25  /1420
# [PROGRAM]: TRAINING batch  26  /1420
# [PROGRAM]: TRAINING batch  27  /1420
# [PROGRAM]: TRAINING batch  28  /1420
# [PROGRAM]: TRAINING batch  29  /1420
# [PROGRAM]: TRAINING batch  30  /1420
# [PROGRAM]: TRAINING batch  31  /1420
# [PROGRAM]: TRAINING batch  32  /1420
# [PROGRAM]: TRAINING batch  33  /1420
# [PROGRAM]: TRAINING batch  34  /1420
# [PROGRAM]: TRAINING batch  35  /1420
# [PROGRAM]: TRAINING batch  36  /1420
# [PROGRAM]: TRAINING batch  37  /1420
# [PROGRAM]: TRAINING batch  38  /1420
# [PROGRAM]: TRAINING batch  39  /1420
# [PROGRAM]: TRAINING batch  40  /1420
# [PROGRAM]: TRAINING batch  41  /1420
# [PROGRAM]: TRAINING batch  42  /1420
# [PROGRAM]: TRAINING batch  43  /1420
# [PROGRAM]: TRAINING batch  44  /1420
# [PROGRAM]: TRAINING batch  45  /1420
# [PROGRAM]: TRAINING batch  46  /1420
# [PROGRAM]: TRAINING batch  47  /1420
# [PROGRAM]: TRAINING batch  48  /1420
# [PROGRAM]: TRAINING batch  49  /1420
# [PROGRAM]: TRAINING batch  50  /1420
# [PROGRAM]: TRAINING batch  51  /1420
# [PROGRAM]: TRAINING batch  52  /1420
# [PROGRAM]: TRAINING batch  53  /1420
# [PROGRAM]: TRAINING batch  54  /1420
# [PROGRAM]: TRAINING batch  55  /1420
# [PROGRAM]: TRAINING batch  56  /1420
# [PROGRAM]: TRAINING batch  57  /1420
# [PROGRAM]: TRAINING batch  58  /1420
# [PROGRAM]: TRAINING batch  59  /1420
# [PROGRAM]: TRAINING batch  60  /1420
# [PROGRAM]: TRAINING batch  61  /1420
# [PROGRAM]: TRAINING batch  253  /1420
# [PROGRAM]: TRAINING batch  254  /1420
# [PROGRAM]: TRAINING batch  255  /1420
# [PROGRAM]: TRAINING batch  256  /1420
# [PROGRAM]: TRAINING batch  257  /1420
# [PROGRAM]: TRAINING batch  258  /1420
# [PROGRAM]: TRAINING batch  259  /1420
# [PROGRAM]: TRAINING batch  260  /1420
# [PROGRAM]: TRAINING batch  261  /1420
# [PROGRAM]: TRAINING batch  262  /1420
# [PROGRAM]: TRAINING batch  263  /1420
# [PROGRAM]: TRAINING batch  264  /1420
# [PROGRAM]: TRAINING batch  265  /1420
# [PROGRAM]: TRAINING batch  266  /1420
# [PROGRAM]: TRAINING batch  267  /1420
# [PROGRAM]: TRAINING batch  268  /1420
# [PROGRAM]: TRAINING batch  269  /1420
# [PROGRAM]: TRAINING batch  270  /1420
# [PROGRAM]: TRAINING batch  271  /1420
# [PROGRAM]: TRAINING batch  272  /1420
# [PROGRAM]: TRAINING batch  273  /1420
# [PROGRAM]: TRAINING batch  274  /1420
# [PROGRAM]: TRAINING batch  275  /1420
# [PROGRAM]: TRAINING batch  276  /1420
# [PROGRAM]: TRAINING batch  277  /1420
# [PROGRAM]: TRAINING batch  278  /1420
# [PROGRAM]: TRAINING batch  279  /1420
# [PROGRAM]: TRAINING batch  280  /1420
# [PROGRAM]: TRAINING batch  281  /1420
# [PROGRAM]: TRAINING batch  282  /1420
# [PROGRAM]: TRAINING batch  283  /1420
# [PROGRAM]: TRAINING batch  284  /1420
# [PROGRAM]: TRAINING batch  285  /1420
# [PROGRAM]: TRAINING batch  286  /1420
# [PROGRAM]: TRAINING batch  287  /1420
# [PROGRAM]: TRAINING batch  288  /1420
# [PROGRAM]: TRAINING batch  289  /1420
# [PROGRAM]: TRAINING batch  290  /1420
# [PROGRAM]: TRAINING batch  291  /1420
# [PROGRAM]: TRAINING batch  292  /1420
# [PROGRAM]: TRAINING batch  293  /1420
# [PROGRAM]: TRAINING batch  294  /1420
# [PROGRAM]: TRAINING batch  295  /1420
# [PROGRAM]: TRAINING batch  296  /1420
# [PROGRAM]: TRAINING batch  297  /1420
# [PROGRAM]: TRAINING batch  298  /1420
# [PROGRAM]: TRAINING batch  299  /1420
# [PROGRAM]: TRAINING batch  300  /1420
# [PROGRAM]: TRAINING batch  301  /1420
# [PROGRAM]: TRAINING batch  302  /1420
# [PROGRAM]: TRAINING batch  303  /1420
# [PROGRAM]: TRAINING batch  304  /1420
# [PROGRAM]: TRAINING batch  305  /1420
# [PROGRAM]: TRAINING batch  306  /1420
# [PROGRAM]: TRAINING batch  307  /1420
# [PROGRAM]: TRAINING batch  308  /1420
# [PROGRAM]: TRAINING batch  309  /1420
# [PROGRAM]: TRAINING batch  310  /1420
# [PROGRAM]: TRAINING batch  311  /1420
# [PROGRAM]: TRAINING batch  312  /1420
# [PROGRAM]: TRAINING batch  313  /1420
# [PROGRAM]: TRAINING batch  314  /1420
# [PROGRAM]: TRAINING batch  315  /1420
# [PROGRAM]: TRAINING batch  379  /1420
# [PROGRAM]: TRAINING batch  380  /1420
# [PROGRAM]: TRAINING batch  381  /1420
# [PROGRAM]: TRAINING batch  382  /1420
# [PROGRAM]: TRAINING batch  383  /1420
# [PROGRAM]: TRAINING batch  384  /1420
# [PROGRAM]: TRAINING batch  385  /1420
# [PROGRAM]: TRAINING batch  386  /1420
# [PROGRAM]: TRAINING batch  387  /1420
# [PROGRAM]: TRAINING batch  388  /1420
# [PROGRAM]: TRAINING batch  389  /1420
# [PROGRAM]: TRAINING batch  390  /1420
# [PROGRAM]: TRAINING batch  391  /1420
# [PROGRAM]: TRAINING batch  392  /1420
# [PROGRAM]: TRAINING batch  393  /1420
# [PROGRAM]: TRAINING batch  394  /1420
# [PROGRAM]: TRAINING batch  395  /1420
# [PROGRAM]: TRAINING batch  396  /1420
# [PROGRAM]: TRAINING batch  397  /1420
# [PROGRAM]: TRAINING batch  398  /1420
# [PROGRAM]: TRAINING batch  399  /1420
# [PROGRAM]: TRAINING batch  400  /1420
# [PROGRAM]: TRAINING batch  401  /1420
# [PROGRAM]: TRAINING batch  402  /1420
# [PROGRAM]: TRAINING batch  403  /1420
# [PROGRAM]: TRAINING batch  404  /1420
# [PROGRAM]: TRAINING batch  405  /1420
# [PROGRAM]: TRAINING batch  406  /1420
# [PROGRAM]: TRAINING batch  407  /1420
# [PROGRAM]: TRAINING batch  408  /1420
# [PROGRAM]: TRAINING batch  409  /1420
# [PROGRAM]: TRAINING batch  410  /1420
# [PROGRAM]: TRAINING batch  411  /1420
# [PROGRAM]: TRAINING batch  412  /1420
# [PROGRAM]: TRAINING batch  413  /1420
# [PROGRAM]: TRAINING batch  414  /1420
# [PROGRAM]: TRAINING batch  415  /1420
# [PROGRAM]: TRAINING batch  416  /1420
# [PROGRAM]: TRAINING batch  417  /1420
# [PROGRAM]: TRAINING batch  418  /1420
# [PROGRAM]: TRAINING batch  419  /1420
# [PROGRAM]: TRAINING batch  420  /1420
# [PROGRAM]: TRAINING batch  421  /1420
# [PROGRAM]: TRAINING batch  422  /1420
# [PROGRAM]: TRAINING batch  423  /1420
# [PROGRAM]: TRAINING batch  424  /1420
# [PROGRAM]: TRAINING batch  425  /1420
# [PROGRAM]: TRAINING batch  426  /1420
# [PROGRAM]: TRAINING batch  427  /1420
# [PROGRAM]: TRAINING batch  428  /1420
# [PROGRAM]: TRAINING batch  429  /1420
# [PROGRAM]: TRAINING batch  430  /1420
# [PROGRAM]: TRAINING batch  431  /1420
# [PROGRAM]: TRAINING batch  432  /1420
# [PROGRAM]: TRAINING batch  433  /1420
# [PROGRAM]: TRAINING batch  434  /1420
# [PROGRAM]: TRAINING batch  435  /1420
# [PROGRAM]: TRAINING batch  436  /1420
# [PROGRAM]: TRAINING batch  437  /1420
# [PROGRAM]: TRAINING batch  438  /1420
# [PROGRAM]: TRAINING batch  439  /1420
# [PROGRAM]: TRAINING batch  440  /1420
# [PROGRAM]: TRAINING batch  441  /1420
# [PROGRAM]: TRAINING batch  442  /1420
# [PROGRAM]: TRAINING batch  506  /1420
# [PROGRAM]: TRAINING batch  507  /1420
# [PROGRAM]: TRAINING batch  508  /1420
# [PROGRAM]: TRAINING batch  509  /1420
# [PROGRAM]: TRAINING batch  510  /1420
# [PROGRAM]: TRAINING batch  511  /1420
# [PROGRAM]: TRAINING batch  512  /1420
# [PROGRAM]: TRAINING batch  513  /1420
# [PROGRAM]: TRAINING batch  514  /1420
# [PROGRAM]: TRAINING batch  515  /1420
# [PROGRAM]: TRAINING batch  516  /1420
# [PROGRAM]: TRAINING batch  517  /1420
# [PROGRAM]: TRAINING batch  518  /1420
# [PROGRAM]: TRAINING batch  519  /1420
# [PROGRAM]: TRAINING batch  520  /1420
# [PROGRAM]: TRAINING batch  521  /1420
# [PROGRAM]: TRAINING batch  522  /1420
# [PROGRAM]: TRAINING batch  523  /1420
# [PROGRAM]: TRAINING batch  524  /1420
# [PROGRAM]: TRAINING batch  525  /1420
# [PROGRAM]: TRAINING batch  526  /1420
# [PROGRAM]: TRAINING batch  527  /1420
# [PROGRAM]: TRAINING batch  528  /1420
# [PROGRAM]: TRAINING batch  529  /1420
# [PROGRAM]: TRAINING batch  530  /1420
# [PROGRAM]: TRAINING batch  531  /1420
# [PROGRAM]: TRAINING batch  532  /1420
# [PROGRAM]: TRAINING batch  533  /1420
# [PROGRAM]: TRAINING batch  534  /1420
# [PROGRAM]: TRAINING batch  535  /1420
# [PROGRAM]: TRAINING batch  536  /1420
# [PROGRAM]: TRAINING batch  537  /1420
# [PROGRAM]: TRAINING batch  538  /1420
# [PROGRAM]: TRAINING batch  539  /1420
# [PROGRAM]: TRAINING batch  540  /1420
# [PROGRAM]: TRAINING batch  541  /1420
# [PROGRAM]: TRAINING batch  542  /1420
# [PROGRAM]: TRAINING batch  543  /1420
# [PROGRAM]: TRAINING batch  544  /1420
# [PROGRAM]: TRAINING batch  545  /1420
# [PROGRAM]: TRAINING batch  546  /1420
# [PROGRAM]: TRAINING batch  547  /1420
# [PROGRAM]: TRAINING batch  548  /1420
# [PROGRAM]: TRAINING batch  549  /1420
# [PROGRAM]: TRAINING batch  550  /1420
# [PROGRAM]: TRAINING batch  551  /1420
# [PROGRAM]: TRAINING batch  552  /1420
# [PROGRAM]: TRAINING batch  553  /1420
# [PROGRAM]: TRAINING batch  554  /1420
# [PROGRAM]: TRAINING batch  555  /1420
# [PROGRAM]: TRAINING batch  556  /1420
# [PROGRAM]: TRAINING batch  557  /1420
# [PROGRAM]: TRAINING batch  558  /1420
# [PROGRAM]: TRAINING batch  559  /1420
# [PROGRAM]: TRAINING batch  560  /1420
# [PROGRAM]: TRAINING batch  561  /1420
# [PROGRAM]: TRAINING batch  562  /1420
# [PROGRAM]: TRAINING batch  563  /1420
# [PROGRAM]: TRAINING batch  564  /1420
# [PROGRAM]: TRAINING batch  565  /1420
# [PROGRAM]: TRAINING batch  566  /1420
# [PROGRAM]: TRAINING batch  567  /1420
# [PROGRAM]: TRAINING batch  568  /1420
# [PROGRAM]: TRAINING batch  569  /1420
# [PROGRAM]: TRAINING batch  760  /1420
# [PROGRAM]: TRAINING batch  761  /1420
# [PROGRAM]: TRAINING batch  762  /1420
# [PROGRAM]: TRAINING batch  763  /1420
# [PROGRAM]: TRAINING batch  764  /1420
# [PROGRAM]: TRAINING batch  765  /1420
# [PROGRAM]: TRAINING batch  766  /1420
# [PROGRAM]: TRAINING batch  767  /1420
# [PROGRAM]: TRAINING batch  768  /1420
# [PROGRAM]: TRAINING batch  769  /1420
# [PROGRAM]: TRAINING batch  770  /1420
# [PROGRAM]: TRAINING batch  771  /1420
# [PROGRAM]: TRAINING batch  772  /1420
# [PROGRAM]: TRAINING batch  773  /1420
# [PROGRAM]: TRAINING batch  774  /1420
# [PROGRAM]: TRAINING batch  775  /1420
# [PROGRAM]: TRAINING batch  776  /1420
# [PROGRAM]: TRAINING batch  777  /1420
# [PROGRAM]: TRAINING batch  778  /1420
# [PROGRAM]: TRAINING batch  779  /1420
# [PROGRAM]: TRAINING batch  780  /1420
# [PROGRAM]: TRAINING batch  781  /1420
# [PROGRAM]: TRAINING batch  782  /1420
# [PROGRAM]: TRAINING batch  783  /1420
# [PROGRAM]: TRAINING batch  784  /1420
# [PROGRAM]: TRAINING batch  785  /1420
# [PROGRAM]: TRAINING batch  786  /1420
# [PROGRAM]: TRAINING batch  787  /1420
# [PROGRAM]: TRAINING batch  788  /1420
# [PROGRAM]: TRAINING batch  789  /1420
# [PROGRAM]: TRAINING batch  790  /1420
# [PROGRAM]: TRAINING batch  791  /1420
# [PROGRAM]: TRAINING batch  792  /1420
# [PROGRAM]: TRAINING batch  793  /1420
# [PROGRAM]: TRAINING batch  794  /1420
# [PROGRAM]: TRAINING batch  795  /1420
# [PROGRAM]: TRAINING batch  796  /1420
# [PROGRAM]: TRAINING batch  797  /1420
# [PROGRAM]: TRAINING batch  798  /1420
# [PROGRAM]: TRAINING batch  799  /1420
# [PROGRAM]: TRAINING batch  800  /1420
# [PROGRAM]: TRAINING batch  801  /1420
# [PROGRAM]: TRAINING batch  802  /1420
# [PROGRAM]: TRAINING batch  803  /1420
# [PROGRAM]: TRAINING batch  804  /1420
# [PROGRAM]: TRAINING batch  805  /1420
# [PROGRAM]: TRAINING batch  806  /1420
# [PROGRAM]: TRAINING batch  807  /1420
# [PROGRAM]: TRAINING batch  808  /1420
# [PROGRAM]: TRAINING batch  809  /1420
# [PROGRAM]: TRAINING batch  810  /1420
# [PROGRAM]: TRAINING batch  811  /1420
# [PROGRAM]: TRAINING batch  812  /1420
# [PROGRAM]: TRAINING batch  813  /1420
# [PROGRAM]: TRAINING batch  814  /1420
# [PROGRAM]: TRAINING batch  815  /1420
# [PROGRAM]: TRAINING batch  816  /1420
# [PROGRAM]: TRAINING batch  817  /1420
# [PROGRAM]: TRAINING batch  818  /1420
# [PROGRAM]: TRAINING batch  819  /1420
# [PROGRAM]: TRAINING batch  820  /1420
# [PROGRAM]: TRAINING batch  821  /1420
# [PROGRAM]: TRAINING batch  822  /1420
# [PROGRAM]: TRAINING batch  1388  /1420
# [PROGRAM]: TRAINING batch  1389  /1420
# [PROGRAM]: TRAINING batch  1390  /1420
# [PROGRAM]: TRAINING batch  1391  /1420
# [PROGRAM]: TRAINING batch  1392  /1420
# [PROGRAM]: TRAINING batch  1393  /1420
# [PROGRAM]: TRAINING batch  1394  /1420
# [PROGRAM]: TRAINING batch  1395  /1420
# [PROGRAM]: TRAINING batch  1396  /1420
# [PROGRAM]: TRAINING batch  1397  /1420
# [PROGRAM]: TRAINING batch  1398  /1420
# [PROGRAM]: TRAINING batch  1399  /1420
# [PROGRAM]: TRAINING batch  1400  /1420
# [PROGRAM]: TRAINING batch  1401  /1420
# [PROGRAM]: TRAINING batch  1402  /1420
# [PROGRAM]: TRAINING batch  1403  /1420
# [PROGRAM]: TRAINING batch  1404  /1420
# [PROGRAM]: TRAINING batch  1405  /1420
# [PROGRAM]: TRAINING batch  1406  /1420
# [PROGRAM]: TRAINING batch  1407  /1420
# [PROGRAM]: TRAINING batch  1408  /1420
# [PROGRAM]: TRAINING batch  1409  /1420
# [PROGRAM]: TRAINING batch  1410  /1420
# [PROGRAM]: TRAINING batch  1411  /1420
# [PROGRAM]: TRAINING batch  1412  /1420
# [PROGRAM]: TRAINING batch  1413  /1420
# [PROGRAM]: TRAINING batch  1414  /1420
# [PROGRAM]: TRAINING batch  1415  /1420
# [PROGRAM]: TRAINING batch  1416  /1420
# [PROGRAM]: TRAINING batch  1417  /1420
# [PROGRAM]: TRAINING batch  1418  /1420
# [PROGRAM]: TRAINING batch  1419  /1420
# [PROGRAM]: TRAINING batch  1420  /1420
# [PROGRAM]: TRAINING batch  1421  /1420
# [PROGRAM]: TRAINING batch  1422  /1420
# [PROGRAM]: TRAINING batch  1423  /1420
# [PROGRAM]: TRAINING batch  1424  /1420
# [PROGRAM]: TRAINING batch  1425  /1420
# [PROGRAM]: TRAINING batch  1426  /1420
# [PROGRAM]: TRAINING batch  1427  /1420
# [PROGRAM]: TRAINING batch  1428  /1420
# [PROGRAM]: TRAINING batch  1429  /1420
# [PROGRAM]: epoch 5
# [PROGRAM]: VALIDATION START
# [PROGRAM]: VALIDATION batch  0
# [PROGRAM]: VALIDATION batch  1
# [PROGRAM]: VALIDATION batch  2
# [PROGRAM]: VALIDATION batch  3
# [PROGRAM]: VALIDATION batch  4
# [PROGRAM]: VALIDATION batch  5
# [PROGRAM]: VALIDATION batch  6
# [PROGRAM]: VALIDATION batch  7
# [PROGRAM]: VALIDATION batch  8
# [PROGRAM]: VALIDATION batch  9
# [PROGRAM]: VALIDATION batch  10
# [PROGRAM]: VALIDATION batch  11
# [PROGRAM]: VALIDATION batch  12
# [PROGRAM]: VALIDATION batch  13
# [PROGRAM]: VALIDATION batch  14
# [PROGRAM]: VALIDATION batch  15
# [PROGRAM]: VALIDATION batch  16
# [PROGRAM]: VALIDATION batch  17
# [PROGRAM]: VALIDATION batch  18
# [PROGRAM]: VALIDATION batch  19
# [PROGRAM]: VALIDATION batch  20
# [PROGRAM]: VALIDATION batch  21
# [PROGRAM]: VALIDATION batch  22
# [PROGRAM]: VALIDATION batch  23
# [PROGRAM]: VALIDATION batch  24
# [PROGRAM]: VALIDATION batch  25
# [PROGRAM]: VALIDATION batch  26
# [PROGRAM]: VALIDATION batch  27
# [PROGRAM]: VALIDATION batch  28
# [PROGRAM]: VALIDATION batch  29
# [PROGRAM]: VALIDATION batch  30
# [PROGRAM]: VALIDATION batch  31
# [PROGRAM]: VALIDATION batch  32
# [PROGRAM]: VALIDATION batch  33
# [PROGRAM]: VALIDATION batch  34
# [PROGRAM]: VALIDATION batch  35
# [PROGRAM]: VALIDATION batch  36
# [PROGRAM]: VALIDATION batch  37
# [PROGRAM]: VALIDATION batch  38
# [PROGRAM]: VALIDATION batch  39
# [PROGRAM]: VALIDATION batch  40
# [PROGRAM]: VALIDATION batch  41
# [PROGRAM]: VALIDATION batch  42
# [PROGRAM]: VALIDATION batch  43
# [PROGRAM]: VALIDATION batch  44
# [PROGRAM]: VALIDATION batch  45
# [PROGRAM]: VALIDATION batch  46
# [PROGRAM]: VALIDATION batch  47
# [PROGRAM]: VALIDATION batch  48
# [PROGRAM]: VALIDATION batch  49
# [PROGRAM]: VALIDATION batch  50
# [PROGRAM]: VALIDATION batch  51
# [PROGRAM]: VALIDATION batch  52
# [PROGRAM]: VALIDATION batch  53
# [PROGRAM]: VALIDATION batch  54
# [PROGRAM]: VALIDATION batch  55
# [PROGRAM]: VALIDATION batch  56
# [PROGRAM]: VALIDATION batch  57
# [PROGRAM]: VALIDATION batch  58
# [PROGRAM]: VALIDATION batch  59
# [PROGRAM]: VALIDATION batch  60
# [PROGRAM]: VALIDATION batch  61
# [PROGRAM]: VALIDATION batch  62
# [PROGRAM]: VALIDATION batch  63
# [PROGRAM]: VALIDATION batch  64
# [PROGRAM]: VALIDATION batch  65
# [PROGRAM]: VALIDATION batch  66
# [PROGRAM]: VALIDATION batch  67
# [PROGRAM]: VALIDATION batch  68
# [PROGRAM]: VALIDATION batch  69
# [PROGRAM]: VALIDATION batch  70
# [PROGRAM]: VALIDATION batch  71
# [PROGRAM]: VALIDATION batch  72
# [PROGRAM]: VALIDATION batch  73
# [PROGRAM]: VALIDATION batch  74
# [PROGRAM]: VALIDATION batch  75
# [PROGRAM]: VALIDATION batch  76
# [PROGRAM]: VALIDATION batch  77
# [PROGRAM]: VALIDATION batch  78
# [PROGRAM]: VALIDATION batch  79
# [PROGRAM]: VALIDATION batch  80
# [PROGRAM]: VALIDATION batch  81
# [PROGRAM]: VALIDATION batch  82
# [PROGRAM]: VALIDATION batch  83
# [PROGRAM]: VALIDATION batch  84
# [PROGRAM]: VALIDATION batch  85
# [PROGRAM]: VALIDATION batch  86
# [PROGRAM]: VALIDATION batch  87
# [PROGRAM]: VALIDATION batch  88
# [PROGRAM]: VALIDATION batch  89
# [PROGRAM]: VALIDATION batch  90
# [PROGRAM]: VALIDATION batch  91
# [PROGRAM]: VALIDATION batch  92
# [PROGRAM]: VALIDATION batch  93
# [PROGRAM]: VALIDATION batch  94
# [PROGRAM]: VALIDATION batch  95
# [PROGRAM]: VALIDATION batch  96
# [PROGRAM]: VALIDATION batch  97
# [PROGRAM]: VALIDATION batch  98
# [PROGRAM]: VALIDATION batch  99
# [PROGRAM]: VALIDATION batch  100
# [PROGRAM]: VALIDATION batch  101
# [PROGRAM]: VALIDATION batch  102
# [PROGRAM]: VALIDATION batch  103
# [PROGRAM]: VALIDATION batch  104
# [PROGRAM]: VALIDATION batch  105
# [PROGRAM]: VALIDATION batch  106
# [PROGRAM]: VALIDATION batch  107
# [PROGRAM]: VALIDATION batch  108
# [PROGRAM]: VALIDATION batch  109
# [PROGRAM]: VALIDATION batch  110
# [PROGRAM]: VALIDATION batch  111
# [PROGRAM]: VALIDATION batch  112
# [PROGRAM]: VALIDATION batch  113
# [PROGRAM]: VALIDATION batch  114
# [PROGRAM]: VALIDATION batch  115
# [PROGRAM]: VALIDATION batch  116
# [PROGRAM]: VALIDATION batch  117
# [PROGRAM]: VALIDATION batch  118
# [PROGRAM]: VALIDATION batch  119
# [PROGRAM]: VALIDATION batch  120
# [PROGRAM]: VALIDATION batch  121
# [PROGRAM]: VALIDATION batch  122
# [PROGRAM]: VALIDATION batch  123
# [PROGRAM]: VALIDATION batch  124
# [PROGRAM]: VALIDATION batch  125
# [PROGRAM]: VALIDATION batch  126
# [PROGRAM]: VALIDATION batch  127
# [PROGRAM]: VALIDATION batch  128
# [PROGRAM]: VALIDATION batch  129
# [PROGRAM]: VALIDATION batch  130
# [PROGRAM]: VALIDATION batch  131
# [PROGRAM]: VALIDATION batch  132
# [PROGRAM]: VALIDATION batch  133
# [PROGRAM]: VALIDATION batch  134
# [PROGRAM]: VALIDATION batch  135
# [PROGRAM]: VALIDATION batch  136
# [PROGRAM]: VALIDATION batch  137
# [PROGRAM]: VALIDATION batch  138
# [PROGRAM]: VALIDATION batch  139
# [PROGRAM]: VALIDATION batch  140
# [PROGRAM]: VALIDATION batch  141
# [PROGRAM]: VALIDATION batch  142
# [PROGRAM]: VALIDATION batch  143
# [PROGRAM]: VALIDATION batch  144
# [PROGRAM]: VALIDATION batch  145
# [PROGRAM]: VALIDATION batch  146
# [PROGRAM]: VALIDATION batch  147
# [PROGRAM]: VALIDATION batch  148
# [PROGRAM]: VALIDATION batch  149
# [PROGRAM]: VALIDATION batch  150
# [PROGRAM]: VALIDATION batch  151
# [PROGRAM]: VALIDATION batch  152
# [PROGRAM]: VALIDATION batch  153
# [PROGRAM]: VALIDATION batch  154
# [PROGRAM]: VALIDATION batch  155
# [PROGRAM]: VALIDATION batch  156
# [PROGRAM]: VALIDATION batch  157
# [PROGRAM]: VALIDATION batch  158
# [PROGRAM]: VALIDATION batch  159
# [PROGRAM]: VALIDATION batch  160
# [PROGRAM]: VALIDATION batch  161
# [PROGRAM]: VALIDATION batch  162
# [PROGRAM]: VALIDATION batch  163
# [PROGRAM]: VALIDATION batch  164
# [PROGRAM]: VALIDATION batch  165
# [PROGRAM]: VALIDATION batch  166
# [PROGRAM]: VALIDATION batch  167
# [PROGRAM]: VALIDATION batch  168
# [PROGRAM]: VALIDATION batch  169
# [PROGRAM]: VALIDATION batch  170
# [PROGRAM]: VALIDATION batch  171
# [PROGRAM]: VALIDATION batch  172
# [PROGRAM]: VALIDATION batch  173
# [PROGRAM]: VALIDATION batch  174
# [PROGRAM]: VALIDATION batch  175
# [PROGRAM]: VALIDATION batch  176
# [PROGRAM]: VALIDATION batch  177
# [PROGRAM]: VALIDATION batch  178
# [PROGRAM]: VALIDATION batch  179
# [PROGRAM]: VALIDATION batch  180
# [PROGRAM]: VALIDATION batch  181
# [PROGRAM]: VALIDATION batch  182
# [PROGRAM]: VALIDATION batch  183
# [PROGRAM]: VALIDATION batch  184
# [PROGRAM]: VALIDATION batch  185
# [PROGRAM]: VALIDATION batch  186
# [PROGRAM]: VALIDATION batch  187
# [PROGRAM]: VALIDATION batch  188
# [PROGRAM]: VALIDATION batch  189
# [PROGRAM]: VALIDATION batch  190
# [PROGRAM]: VALIDATION batch  191
# [PROGRAM]: VALIDATION batch  192
# [PROGRAM]: VALIDATION batch  193
# [PROGRAM]: VALIDATION batch  194
# [PROGRAM]: VALIDATION batch  195
# [PROGRAM]: VALIDATION batch  196
# [PROGRAM]: VALIDATION batch  197
# [PROGRAM]: VALIDATION batch  198
# [PROGRAM]: VALIDATION batch  199
# [PROGRAM]: VALIDATION batch  200
# [PROGRAM]: VALIDATION batch  201
# [PROGRAM]: VALIDATION batch  202
# [PROGRAM]: VALIDATION batch  203
# [PROGRAM]: VALIDATION batch  204
# [PROGRAM]: VALIDATION batch  205
# [PROGRAM]: VALIDATION batch  206
# [PROGRAM]: VALIDATION batch  207
# [PROGRAM]: VALIDATION batch  208
# [PROGRAM]: VALIDATION batch  209
# [PROGRAM]: VALIDATION batch  210
# [PROGRAM]: VALIDATION batch  211
# [PROGRAM]: VALIDATION batch  212
# [PROGRAM]: VALIDATION batch  213
# [PROGRAM]: VALIDATION batch  214
# [PROGRAM]: VALIDATION batch  215
# [PROGRAM]: VALIDATION batch  216
# [PROGRAM]: VALIDATION batch  217
# [PROGRAM]: VALIDATION batch  218
# [PROGRAM]: VALIDATION batch  219
# [PROGRAM]: VALIDATION batch  220
# [PROGRAM]: VALIDATION batch  221
# [PROGRAM]: VALIDATION batch  222
# [PROGRAM]: VALIDATION batch  223
# [PROGRAM]: VALIDATION batch  224
# [PROGRAM]: VALIDATION batch  225
# [PROGRAM]: VALIDATION batch  226
# [PROGRAM]: VALIDATION batch  227
# [PROGRAM]: VALIDATION batch  228
# [PROGRAM]: VALIDATION batch  229
# [PROGRAM]: VALIDATION batch  230
# [PROGRAM]: VALIDATION batch  231
# [PROGRAM]: VALIDATION batch  232
# [PROGRAM]: VALIDATION batch  233
# [PROGRAM]: VALIDATION batch  234
# [PROGRAM]: VALIDATION batch  235
# [PROGRAM]: VALIDATION batch  236
# [PROGRAM]: VALIDATION batch  237
# [PROGRAM]: VALIDATION batch  238
# [PROGRAM]: VALIDATION batch  239
# [PROGRAM]: VALIDATION batch  240
# [PROGRAM]: VALIDATION batch  241
# [PROGRAM]: VALIDATION batch  242
# [PROGRAM]: VALIDATION batch  243
# [PROGRAM]: VALIDATION batch  244
# [PROGRAM]: VALIDATION batch  245
# [PROGRAM]: VALIDATION batch  246
# [PROGRAM]: VALIDATION batch  247
# [PROGRAM]: VALIDATION batch  248
# [PROGRAM]: VALIDATION batch  249
# [PROGRAM]: VALIDATION batch  250
# [PROGRAM]: VALIDATION batch  251
# [PROGRAM]: VALIDATION batch  252
# [PROGRAM]: VALIDATION batch  253
# [PROGRAM]: VALIDATION batch  254
# [PROGRAM]: VALIDATION batch  255
# [PROGRAM]: VALIDATION batch  256
# [PROGRAM]: VALIDATION batch  257
# [PROGRAM]: VALIDATION batch  258
# [PROGRAM]: VALIDATION batch  259
# [PROGRAM]: VALIDATION batch  260
# [PROGRAM]: VALIDATION batch  261
# [PROGRAM]: VALIDATION batch  262
# [PROGRAM]: VALIDATION batch  263
# [PROGRAM]: VALIDATION batch  264
# [PROGRAM]: VALIDATION batch  265
# [PROGRAM]: VALIDATION batch  266
# [PROGRAM]: VALIDATION batch  267
# [PROGRAM]: VALIDATION batch  268
# [PROGRAM]: VALIDATION batch  269
# [PROGRAM]: VALIDATION batch  270
# [PROGRAM]: VALIDATION batch  271
# [PROGRAM]: VALIDATION batch  272
# [PROGRAM]: VALIDATION batch  273
# [PROGRAM]: VALIDATION batch  274
# [PROGRAM]: VALIDATION batch  275
# [PROGRAM]: VALIDATION batch  276
# [PROGRAM]: VALIDATION batch  277
# [PROGRAM]: VALIDATION batch  278
# [PROGRAM]: VALIDATION batch  279
# [PROGRAM]: VALIDATION batch  280
# [PROGRAM]: VALIDATION batch  281
# [PROGRAM]: VALIDATION batch  282
# [PROGRAM]: VALIDATION batch  283
# [PROGRAM]: VALIDATION batch  284
# [PROGRAM]: VALIDATION batch  285
# [PROGRAM]: VALIDATION batch  286
# [PROGRAM]: VALIDATION batch  287
# [PROGRAM]: VALIDATION batch  288
# [PROGRAM]: VALIDATION batch  289
# [PROGRAM]: VALIDATION batch  290
# [PROGRAM]: VALIDATION batch  291
# [PROGRAM]: VALIDATION batch  292
# [PROGRAM]: VALIDATION batch  293
# [PROGRAM]: VALIDATION batch  294
# [PROGRAM]: VALIDATION batch  295
# [PROGRAM]: VALIDATION batch  296
# [PROGRAM]: VALIDATION batch  297
# [PROGRAM]: VALIDATION batch  298
# [PROGRAM]: VALIDATION batch  299
# [PROGRAM]: VALIDATION batch  300
# [PROGRAM]: VALIDATION batch  301
# [PROGRAM]: VALIDATION batch  302
# [PROGRAM]: VALIDATION batch  303
# [PROGRAM]: VALIDATION batch  304
# [PROGRAM]: VALIDATION batch  305
# [PROGRAM]: VALIDATION batch  306
# [PROGRAM]: VALIDATION batch  307
# [PROGRAM]: VALIDATION batch  308
# [PROGRAM]: VALIDATION batch  309
# [PROGRAM]: VALIDATION batch  310
# [PROGRAM]: VALIDATION batch  311
# [PROGRAM]: VALIDATION batch  312
# [PROGRAM]: VALIDATION batch  313
# [PROGRAM]: VALIDATION batch  314
# [PROGRAM]: VALIDATION batch  315
# [PROGRAM]: VALIDATION batch  316
# [PROGRAM]: VALIDATION batch  317
# [PROGRAM]: VALIDATION batch  318
# [PROGRAM]: VALIDATION batch  319
# [PROGRAM]: VALIDATION batch  320
# [PROGRAM]: VALIDATION batch  321
# [PROGRAM]: VALIDATION batch  322
# [PROGRAM]: VALIDATION batch  323
# [PROGRAM]: VALIDATION batch  324
# [PROGRAM]: VALIDATION batch  325
# [PROGRAM]: VALIDATION batch  326
# [PROGRAM]: VALIDATION batch  327
# [PROGRAM]: VALIDATION batch  328
# [PROGRAM]: VALIDATION batch  329
# [PROGRAM]: VALIDATION batch  330
# [PROGRAM]: VALIDATION batch  331
# [PROGRAM]: VALIDATION batch  332
# [PROGRAM]: VALIDATION batch  333
# [PROGRAM]: VALIDATION batch  334
# [PROGRAM]: VALIDATION batch  335
# [PROGRAM]: VALIDATION batch  336
# [PROGRAM]: VALIDATION batch  337
# [PROGRAM]: VALIDATION batch  338
# [PROGRAM]: VALIDATION batch  339
# [PROGRAM]: VALIDATION batch  340
# [PROGRAM]: VALIDATION batch  341
# [PROGRAM]: VALIDATION batch  342
# [PROGRAM]: VALIDATION batch  343
# [PROGRAM]: VALIDATION batch  344
# [PROGRAM]: VALIDATION batch  345
# [PROGRAM]: VALIDATION batch  346
# [PROGRAM]: VALIDATION batch  347
# [PROGRAM]: VALIDATION batch  348
# [PROGRAM]: VALIDATION batch  349
# [PROGRAM]: VALIDATION batch  350
# [PROGRAM]: VALIDATION batch  351
# [PROGRAM]: VALIDATION batch  352
# [PROGRAM]: VALIDATION batch  353
# [PROGRAM]: VALIDATION batch  354
# [PROGRAM]: VALIDATION batch  355
# [PROGRAM]: VALIDATION batch  356
# [PROGRAM]: VALIDATION batch  357
# [PROGRAM]: VALIDATION END
# [PROGRAM]: Epoch: 5 	Avgerage Training Loss: 0.000022 	Average Validation Loss: 0.000087
# [PROGRAM]: Epoch: 5 	Avgerage Training Loss: 0.000022	Avgerage Val Loss: 0.000087
# [PROGRAM]: Validation loss decreased (0.000094 --> 0.000087).  Saving model ...
# [PROGRAM]: Epoch 5  Done

# %%
def score_avg(y_pred, y_test):
    precision = precision_score(y_test, y_pred, average='micro')
    recall = recall_score(y_test, y_pred, average='micro')
    f1 = f1_score(y_test, y_pred, average='micro')
    hamming = hamming_loss(y_test, y_pred)
    jacard = jaccard_score(y_test, y_pred, average='micro')

    print("[PROGRAM]: classifier -> BERT finetuned")
    print("[PROGRAM]: avg precision: {}".format(precision))
    print("[PROGRAM]: avg recall: {}".format(recall))
    print("[PROGRAM]: avg f1-score: {}".format(f1))
    print("[PROGRAM]: avg hamming loss: {}".format(hamming))
    print("[PROGRAM]: avg jacard score: {}".format(jacard))

    return [precision, recall, f1, hamming, jacard]

# %%
model.eval()
y_test = []
y_pred = []
with torch.no_grad():
    for batch_idx, data in enumerate(test_loader, 0):
        ids = data['ids'].to(device, dtype = torch.long)
        mask = data['mask'].to(device, dtype = torch.long)
        token_type_ids = data['token_type_ids'].to(device, dtype = torch.long)
        targets = data['targets'].to(device, dtype = torch.float)
        outputs = model(ids, mask, token_type_ids)
        y_test.extend(targets.cpu().detach().numpy().tolist())
        y_pred.extend(torch.sigmoid(outputs).cpu().detach().numpy().tolist())
        print("[PROGRAM]: INFERENCE BATCH ", batch_idx," /446")

# applying hard map of probas into (0,1)
y_pred = (np.array(y_pred) > 0.5).astype(int)
y_pred = np.array(y_pred)
y_test = np.array(y_test)
# Out:
# [PROGRAM]: INFERENCE BATCH  0  /446
# [PROGRAM]: INFERENCE BATCH  1  /446
# [PROGRAM]: INFERENCE BATCH  2  /446
# [PROGRAM]: INFERENCE BATCH  3  /446
# [PROGRAM]: INFERENCE BATCH  4  /446
# [PROGRAM]: INFERENCE BATCH  5  /446
# [PROGRAM]: INFERENCE BATCH  6  /446
# [PROGRAM]: INFERENCE BATCH  7  /446
# [PROGRAM]: INFERENCE BATCH  8  /446
# [PROGRAM]: INFERENCE BATCH  9  /446
# [PROGRAM]: INFERENCE BATCH  10  /446
# [PROGRAM]: INFERENCE BATCH  11  /446
# [PROGRAM]: INFERENCE BATCH  12  /446
# [PROGRAM]: INFERENCE BATCH  13  /446
# [PROGRAM]: INFERENCE BATCH  14  /446
# [PROGRAM]: INFERENCE BATCH  15  /446
# [PROGRAM]: INFERENCE BATCH  16  /446
# [PROGRAM]: INFERENCE BATCH  17  /446
# [PROGRAM]: INFERENCE BATCH  18  /446
# [PROGRAM]: INFERENCE BATCH  19  /446
# [PROGRAM]: INFERENCE BATCH  20  /446
# [PROGRAM]: INFERENCE BATCH  21  /446
# [PROGRAM]: INFERENCE BATCH  22  /446
# [PROGRAM]: INFERENCE BATCH  23  /446
# [PROGRAM]: INFERENCE BATCH  24  /446
# [PROGRAM]: INFERENCE BATCH  25  /446
# [PROGRAM]: INFERENCE BATCH  26  /446
# [PROGRAM]: INFERENCE BATCH  27  /446
# [PROGRAM]: INFERENCE BATCH  28  /446
# [PROGRAM]: INFERENCE BATCH  29  /446
# [PROGRAM]: INFERENCE BATCH  30  /446
# [PROGRAM]: INFERENCE BATCH  31  /446
# [PROGRAM]: INFERENCE BATCH  32  /446
# [PROGRAM]: INFERENCE BATCH  33  /446
# [PROGRAM]: INFERENCE BATCH  34  /446
# [PROGRAM]: INFERENCE BATCH  35  /446
# [PROGRAM]: INFERENCE BATCH  36  /446
# [PROGRAM]: INFERENCE BATCH  37  /446
# [PROGRAM]: INFERENCE BATCH  38  /446
# [PROGRAM]: INFERENCE BATCH  39  /446
# [PROGRAM]: INFERENCE BATCH  40  /446
# [PROGRAM]: INFERENCE BATCH  41  /446
# [PROGRAM]: INFERENCE BATCH  42  /446
# [PROGRAM]: INFERENCE BATCH  43  /446
# [PROGRAM]: INFERENCE BATCH  44  /446
# [PROGRAM]: INFERENCE BATCH  45  /446
# [PROGRAM]: INFERENCE BATCH  46  /446
# [PROGRAM]: INFERENCE BATCH  47  /446
# [PROGRAM]: INFERENCE BATCH  48  /446
# [PROGRAM]: INFERENCE BATCH  49  /446
# [PROGRAM]: INFERENCE BATCH  50  /446
# [PROGRAM]: INFERENCE BATCH  51  /446
# [PROGRAM]: INFERENCE BATCH  52  /446
# [PROGRAM]: INFERENCE BATCH  53  /446
# [PROGRAM]: INFERENCE BATCH  54  /446
# [PROGRAM]: INFERENCE BATCH  55  /446
# [PROGRAM]: INFERENCE BATCH  56  /446
# [PROGRAM]: INFERENCE BATCH  57  /446
# [PROGRAM]: INFERENCE BATCH  58  /446
# [PROGRAM]: INFERENCE BATCH  59  /446
# [PROGRAM]: INFERENCE BATCH  60  /446
# [PROGRAM]: INFERENCE BATCH  61  /446
# [PROGRAM]: INFERENCE BATCH  62  /446
# [PROGRAM]: INFERENCE BATCH  63  /446
# [PROGRAM]: INFERENCE BATCH  64  /446
# [PROGRAM]: INFERENCE BATCH  65  /446
# [PROGRAM]: INFERENCE BATCH  66  /446
# [PROGRAM]: INFERENCE BATCH  67  /446
# [PROGRAM]: INFERENCE BATCH  68  /446
# [PROGRAM]: INFERENCE BATCH  69  /446
# [PROGRAM]: INFERENCE BATCH  70  /446
# [PROGRAM]: INFERENCE BATCH  71  /446
# [PROGRAM]: INFERENCE BATCH  72  /446
# [PROGRAM]: INFERENCE BATCH  73  /446
# [PROGRAM]: INFERENCE BATCH  74  /446
# [PROGRAM]: INFERENCE BATCH  75  /446
# [PROGRAM]: INFERENCE BATCH  76  /446
# [PROGRAM]: INFERENCE BATCH  77  /446
# [PROGRAM]: INFERENCE BATCH  78  /446
# [PROGRAM]: INFERENCE BATCH  79  /446
# [PROGRAM]: INFERENCE BATCH  80  /446
# [PROGRAM]: INFERENCE BATCH  81  /446
# [PROGRAM]: INFERENCE BATCH  82  /446
# [PROGRAM]: INFERENCE BATCH  83  /446
# [PROGRAM]: INFERENCE BATCH  84  /446
# [PROGRAM]: INFERENCE BATCH  85  /446
# [PROGRAM]: INFERENCE BATCH  86  /446
# [PROGRAM]: INFERENCE BATCH  87  /446
# [PROGRAM]: INFERENCE BATCH  88  /446
# [PROGRAM]: INFERENCE BATCH  89  /446
# [PROGRAM]: INFERENCE BATCH  90  /446
# [PROGRAM]: INFERENCE BATCH  91  /446
# [PROGRAM]: INFERENCE BATCH  92  /446
# [PROGRAM]: INFERENCE BATCH  93  /446
# [PROGRAM]: INFERENCE BATCH  94  /446
# [PROGRAM]: INFERENCE BATCH  95  /446
# [PROGRAM]: INFERENCE BATCH  96  /446
# [PROGRAM]: INFERENCE BATCH  97  /446
# [PROGRAM]: INFERENCE BATCH  98  /446
# [PROGRAM]: INFERENCE BATCH  99  /446
# [PROGRAM]: INFERENCE BATCH  100  /446
# [PROGRAM]: INFERENCE BATCH  101  /446
# [PROGRAM]: INFERENCE BATCH  102  /446
# [PROGRAM]: INFERENCE BATCH  103  /446
# [PROGRAM]: INFERENCE BATCH  104  /446
# [PROGRAM]: INFERENCE BATCH  105  /446
# [PROGRAM]: INFERENCE BATCH  106  /446
# [PROGRAM]: INFERENCE BATCH  107  /446
# [PROGRAM]: INFERENCE BATCH  108  /446
# [PROGRAM]: INFERENCE BATCH  109  /446
# [PROGRAM]: INFERENCE BATCH  110  /446
# [PROGRAM]: INFERENCE BATCH  111  /446
# [PROGRAM]: INFERENCE BATCH  112  /446
# [PROGRAM]: INFERENCE BATCH  113  /446
# [PROGRAM]: INFERENCE BATCH  114  /446
# [PROGRAM]: INFERENCE BATCH  115  /446
# [PROGRAM]: INFERENCE BATCH  116  /446
# [PROGRAM]: INFERENCE BATCH  117  /446
# [PROGRAM]: INFERENCE BATCH  118  /446
# [PROGRAM]: INFERENCE BATCH  119  /446
# [PROGRAM]: INFERENCE BATCH  120  /446
# [PROGRAM]: INFERENCE BATCH  121  /446
# [PROGRAM]: INFERENCE BATCH  122  /446
# [PROGRAM]: INFERENCE BATCH  123  /446
# [PROGRAM]: INFERENCE BATCH  124  /446
# [PROGRAM]: INFERENCE BATCH  125  /446
# [PROGRAM]: INFERENCE BATCH  126  /446
# [PROGRAM]: INFERENCE BATCH  127  /446
# [PROGRAM]: INFERENCE BATCH  128  /446
# [PROGRAM]: INFERENCE BATCH  129  /446
# [PROGRAM]: INFERENCE BATCH  130  /446
# [PROGRAM]: INFERENCE BATCH  131  /446
# [PROGRAM]: INFERENCE BATCH  132  /446
# [PROGRAM]: INFERENCE BATCH  133  /446
# [PROGRAM]: INFERENCE BATCH  134  /446
# [PROGRAM]: INFERENCE BATCH  135  /446
# [PROGRAM]: INFERENCE BATCH  136  /446
# [PROGRAM]: INFERENCE BATCH  137  /446
# [PROGRAM]: INFERENCE BATCH  138  /446
# [PROGRAM]: INFERENCE BATCH  139  /446
# [PROGRAM]: INFERENCE BATCH  140  /446
# [PROGRAM]: INFERENCE BATCH  141  /446
# [PROGRAM]: INFERENCE BATCH  142  /446
# [PROGRAM]: INFERENCE BATCH  143  /446
# [PROGRAM]: INFERENCE BATCH  144  /446
# [PROGRAM]: INFERENCE BATCH  145  /446
# [PROGRAM]: INFERENCE BATCH  146  /446
# [PROGRAM]: INFERENCE BATCH  147  /446
# [PROGRAM]: INFERENCE BATCH  148  /446
# [PROGRAM]: INFERENCE BATCH  149  /446
# [PROGRAM]: INFERENCE BATCH  150  /446
# [PROGRAM]: INFERENCE BATCH  151  /446
# [PROGRAM]: INFERENCE BATCH  152  /446
# [PROGRAM]: INFERENCE BATCH  153  /446
# [PROGRAM]: INFERENCE BATCH  154  /446
# [PROGRAM]: INFERENCE BATCH  155  /446
# [PROGRAM]: INFERENCE BATCH  156  /446
# [PROGRAM]: INFERENCE BATCH  157  /446
# [PROGRAM]: INFERENCE BATCH  158  /446
# [PROGRAM]: INFERENCE BATCH  159  /446
# [PROGRAM]: INFERENCE BATCH  160  /446
# [PROGRAM]: INFERENCE BATCH  161  /446
# [PROGRAM]: INFERENCE BATCH  162  /446
# [PROGRAM]: INFERENCE BATCH  163  /446
# [PROGRAM]: INFERENCE BATCH  164  /446
# [PROGRAM]: INFERENCE BATCH  165  /446
# [PROGRAM]: INFERENCE BATCH  166  /446
# [PROGRAM]: INFERENCE BATCH  167  /446
# [PROGRAM]: INFERENCE BATCH  168  /446
# [PROGRAM]: INFERENCE BATCH  169  /446
# [PROGRAM]: INFERENCE BATCH  170  /446
# [PROGRAM]: INFERENCE BATCH  171  /446
# [PROGRAM]: INFERENCE BATCH  172  /446
# [PROGRAM]: INFERENCE BATCH  173  /446
# [PROGRAM]: INFERENCE BATCH  174  /446
# [PROGRAM]: INFERENCE BATCH  175  /446
# [PROGRAM]: INFERENCE BATCH  176  /446
# [PROGRAM]: INFERENCE BATCH  177  /446
# [PROGRAM]: INFERENCE BATCH  178  /446
# [PROGRAM]: INFERENCE BATCH  179  /446
# [PROGRAM]: INFERENCE BATCH  180  /446
# [PROGRAM]: INFERENCE BATCH  181  /446
# [PROGRAM]: INFERENCE BATCH  182  /446
# [PROGRAM]: INFERENCE BATCH  183  /446
# [PROGRAM]: INFERENCE BATCH  184  /446
# [PROGRAM]: INFERENCE BATCH  185  /446
# [PROGRAM]: INFERENCE BATCH  186  /446
# [PROGRAM]: INFERENCE BATCH  187  /446
# [PROGRAM]: INFERENCE BATCH  188  /446
# [PROGRAM]: INFERENCE BATCH  189  /446
# [PROGRAM]: INFERENCE BATCH  190  /446
# [PROGRAM]: INFERENCE BATCH  191  /446
# [PROGRAM]: INFERENCE BATCH  192  /446
# [PROGRAM]: INFERENCE BATCH  193  /446
# [PROGRAM]: INFERENCE BATCH  194  /446
# [PROGRAM]: INFERENCE BATCH  195  /446
# [PROGRAM]: INFERENCE BATCH  196  /446
# [PROGRAM]: INFERENCE BATCH  197  /446
# [PROGRAM]: INFERENCE BATCH  198  /446
# [PROGRAM]: INFERENCE BATCH  199  /446
# [PROGRAM]: INFERENCE BATCH  200  /446
# [PROGRAM]: INFERENCE BATCH  201  /446
# [PROGRAM]: INFERENCE BATCH  202  /446
# [PROGRAM]: INFERENCE BATCH  203  /446
# [PROGRAM]: INFERENCE BATCH  204  /446
# [PROGRAM]: INFERENCE BATCH  205  /446
# [PROGRAM]: INFERENCE BATCH  206  /446
# [PROGRAM]: INFERENCE BATCH  207  /446
# [PROGRAM]: INFERENCE BATCH  208  /446
# [PROGRAM]: INFERENCE BATCH  209  /446
# [PROGRAM]: INFERENCE BATCH  210  /446
# [PROGRAM]: INFERENCE BATCH  211  /446
# [PROGRAM]: INFERENCE BATCH  212  /446
# [PROGRAM]: INFERENCE BATCH  213  /446
# [PROGRAM]: INFERENCE BATCH  214  /446
# [PROGRAM]: INFERENCE BATCH  215  /446
# [PROGRAM]: INFERENCE BATCH  216  /446
# [PROGRAM]: INFERENCE BATCH  217  /446
# [PROGRAM]: INFERENCE BATCH  218  /446
# [PROGRAM]: INFERENCE BATCH  219  /446
# [PROGRAM]: INFERENCE BATCH  220  /446
# [PROGRAM]: INFERENCE BATCH  221  /446
# [PROGRAM]: INFERENCE BATCH  222  /446
# [PROGRAM]: INFERENCE BATCH  223  /446
# [PROGRAM]: INFERENCE BATCH  224  /446
# [PROGRAM]: INFERENCE BATCH  225  /446
# [PROGRAM]: INFERENCE BATCH  226  /446
# [PROGRAM]: INFERENCE BATCH  227  /446
# [PROGRAM]: INFERENCE BATCH  228  /446
# [PROGRAM]: INFERENCE BATCH  229  /446
# [PROGRAM]: INFERENCE BATCH  230  /446
# [PROGRAM]: INFERENCE BATCH  231  /446
# [PROGRAM]: INFERENCE BATCH  232  /446
# [PROGRAM]: INFERENCE BATCH  233  /446
# [PROGRAM]: INFERENCE BATCH  234  /446
# [PROGRAM]: INFERENCE BATCH  235  /446
# [PROGRAM]: INFERENCE BATCH  236  /446
# [PROGRAM]: INFERENCE BATCH  237  /446
# [PROGRAM]: INFERENCE BATCH  238  /446
# [PROGRAM]: INFERENCE BATCH  239  /446
# [PROGRAM]: INFERENCE BATCH  240  /446
# [PROGRAM]: INFERENCE BATCH  241  /446
# [PROGRAM]: INFERENCE BATCH  242  /446
# [PROGRAM]: INFERENCE BATCH  243  /446
# [PROGRAM]: INFERENCE BATCH  244  /446
# [PROGRAM]: INFERENCE BATCH  245  /446
# [PROGRAM]: INFERENCE BATCH  246  /446
# [PROGRAM]: INFERENCE BATCH  247  /446
# [PROGRAM]: INFERENCE BATCH  248  /446
# [PROGRAM]: INFERENCE BATCH  249  /446
# [PROGRAM]: INFERENCE BATCH  250  /446
# [PROGRAM]: INFERENCE BATCH  251  /446
# [PROGRAM]: INFERENCE BATCH  252  /446
# [PROGRAM]: INFERENCE BATCH  253  /446
# [PROGRAM]: INFERENCE BATCH  254  /446
# [PROGRAM]: INFERENCE BATCH  255  /446
# [PROGRAM]: INFERENCE BATCH  256  /446
# [PROGRAM]: INFERENCE BATCH  257  /446
# [PROGRAM]: INFERENCE BATCH  258  /446
# [PROGRAM]: INFERENCE BATCH  259  /446
# [PROGRAM]: INFERENCE BATCH  260  /446
# [PROGRAM]: INFERENCE BATCH  261  /446
# [PROGRAM]: INFERENCE BATCH  262  /446
# [PROGRAM]: INFERENCE BATCH  263  /446
# [PROGRAM]: INFERENCE BATCH  264  /446
# [PROGRAM]: INFERENCE BATCH  265  /446
# [PROGRAM]: INFERENCE BATCH  266  /446
# [PROGRAM]: INFERENCE BATCH  267  /446
# [PROGRAM]: INFERENCE BATCH  268  /446
# [PROGRAM]: INFERENCE BATCH  269  /446
# [PROGRAM]: INFERENCE BATCH  270  /446
# [PROGRAM]: INFERENCE BATCH  271  /446
# [PROGRAM]: INFERENCE BATCH  272  /446
# [PROGRAM]: INFERENCE BATCH  273  /446
# [PROGRAM]: INFERENCE BATCH  274  /446
# [PROGRAM]: INFERENCE BATCH  275  /446
# [PROGRAM]: INFERENCE BATCH  276  /446
# [PROGRAM]: INFERENCE BATCH  277  /446
# [PROGRAM]: INFERENCE BATCH  278  /446
# [PROGRAM]: INFERENCE BATCH  279  /446
# [PROGRAM]: INFERENCE BATCH  280  /446
# [PROGRAM]: INFERENCE BATCH  281  /446
# [PROGRAM]: INFERENCE BATCH  282  /446
# [PROGRAM]: INFERENCE BATCH  283  /446
# [PROGRAM]: INFERENCE BATCH  284  /446
# [PROGRAM]: INFERENCE BATCH  285  /446
# [PROGRAM]: INFERENCE BATCH  286  /446
# [PROGRAM]: INFERENCE BATCH  287  /446
# [PROGRAM]: INFERENCE BATCH  288  /446
# [PROGRAM]: INFERENCE BATCH  289  /446
# [PROGRAM]: INFERENCE BATCH  290  /446
# [PROGRAM]: INFERENCE BATCH  291  /446
# [PROGRAM]: INFERENCE BATCH  292  /446
# [PROGRAM]: INFERENCE BATCH  293  /446
# [PROGRAM]: INFERENCE BATCH  294  /446
# [PROGRAM]: INFERENCE BATCH  295  /446
# [PROGRAM]: INFERENCE BATCH  296  /446
# [PROGRAM]: INFERENCE BATCH  297  /446
# [PROGRAM]: INFERENCE BATCH  298  /446
# [PROGRAM]: INFERENCE BATCH  299  /446
# [PROGRAM]: INFERENCE BATCH  300  /446
# [PROGRAM]: INFERENCE BATCH  301  /446
# [PROGRAM]: INFERENCE BATCH  302  /446
# [PROGRAM]: INFERENCE BATCH  303  /446
# [PROGRAM]: INFERENCE BATCH  304  /446
# [PROGRAM]: INFERENCE BATCH  305  /446
# [PROGRAM]: INFERENCE BATCH  306  /446
# [PROGRAM]: INFERENCE BATCH  307  /446
# [PROGRAM]: INFERENCE BATCH  308  /446
# [PROGRAM]: INFERENCE BATCH  309  /446
# [PROGRAM]: INFERENCE BATCH  310  /446
# [PROGRAM]: INFERENCE BATCH  311  /446
# [PROGRAM]: INFERENCE BATCH  312  /446
# [PROGRAM]: INFERENCE BATCH  313  /446
# [PROGRAM]: INFERENCE BATCH  314  /446
# [PROGRAM]: INFERENCE BATCH  315  /446
# [PROGRAM]: INFERENCE BATCH  316  /446
# [PROGRAM]: INFERENCE BATCH  317  /446
# [PROGRAM]: INFERENCE BATCH  318  /446
# [PROGRAM]: INFERENCE BATCH  319  /446
# [PROGRAM]: INFERENCE BATCH  320  /446
# [PROGRAM]: INFERENCE BATCH  321  /446
# [PROGRAM]: INFERENCE BATCH  322  /446
# [PROGRAM]: INFERENCE BATCH  323  /446
# [PROGRAM]: INFERENCE BATCH  324  /446
# [PROGRAM]: INFERENCE BATCH  325  /446
# [PROGRAM]: INFERENCE BATCH  326  /446
# [PROGRAM]: INFERENCE BATCH  327  /446
# [PROGRAM]: INFERENCE BATCH  328  /446
# [PROGRAM]: INFERENCE BATCH  329  /446
# [PROGRAM]: INFERENCE BATCH  330  /446
# [PROGRAM]: INFERENCE BATCH  331  /446
# [PROGRAM]: INFERENCE BATCH  332  /446
# [PROGRAM]: INFERENCE BATCH  333  /446
# [PROGRAM]: INFERENCE BATCH  334  /446
# [PROGRAM]: INFERENCE BATCH  335  /446
# [PROGRAM]: INFERENCE BATCH  336  /446
# [PROGRAM]: INFERENCE BATCH  337  /446
# [PROGRAM]: INFERENCE BATCH  338  /446
# [PROGRAM]: INFERENCE BATCH  339  /446
# [PROGRAM]: INFERENCE BATCH  340  /446
# [PROGRAM]: INFERENCE BATCH  341  /446
# [PROGRAM]: INFERENCE BATCH  342  /446
# [PROGRAM]: INFERENCE BATCH  343  /446
# [PROGRAM]: INFERENCE BATCH  344  /446
# [PROGRAM]: INFERENCE BATCH  345  /446
# [PROGRAM]: INFERENCE BATCH  346  /446
# [PROGRAM]: INFERENCE BATCH  347  /446
# [PROGRAM]: INFERENCE BATCH  348  /446
# [PROGRAM]: INFERENCE BATCH  349  /446
# [PROGRAM]: INFERENCE BATCH  350  /446
# [PROGRAM]: INFERENCE BATCH  351  /446
# [PROGRAM]: INFERENCE BATCH  352  /446
# [PROGRAM]: INFERENCE BATCH  353  /446
# [PROGRAM]: INFERENCE BATCH  354  /446
# [PROGRAM]: INFERENCE BATCH  355  /446
# [PROGRAM]: INFERENCE BATCH  356  /446
# [PROGRAM]: INFERENCE BATCH  357  /446
# [PROGRAM]: INFERENCE BATCH  358  /446
# [PROGRAM]: INFERENCE BATCH  359  /446
# [PROGRAM]: INFERENCE BATCH  360  /446
# [PROGRAM]: INFERENCE BATCH  361  /446
# [PROGRAM]: INFERENCE BATCH  362  /446
# [PROGRAM]: INFERENCE BATCH  363  /446
# [PROGRAM]: INFERENCE BATCH  364  /446
# [PROGRAM]: INFERENCE BATCH  365  /446
# [PROGRAM]: INFERENCE BATCH  366  /446
# [PROGRAM]: INFERENCE BATCH  367  /446
# [PROGRAM]: INFERENCE BATCH  368  /446
# [PROGRAM]: INFERENCE BATCH  369  /446
# [PROGRAM]: INFERENCE BATCH  370  /446
# [PROGRAM]: INFERENCE BATCH  371  /446
# [PROGRAM]: INFERENCE BATCH  372  /446
# [PROGRAM]: INFERENCE BATCH  373  /446
# [PROGRAM]: INFERENCE BATCH  374  /446
# [PROGRAM]: INFERENCE BATCH  375  /446
# [PROGRAM]: INFERENCE BATCH  376  /446
# [PROGRAM]: INFERENCE BATCH  377  /446
# [PROGRAM]: INFERENCE BATCH  378  /446
# [PROGRAM]: INFERENCE BATCH  379  /446
# [PROGRAM]: INFERENCE BATCH  380  /446
# [PROGRAM]: INFERENCE BATCH  381  /446
# [PROGRAM]: INFERENCE BATCH  382  /446
# [PROGRAM]: INFERENCE BATCH  383  /446
# [PROGRAM]: INFERENCE BATCH  384  /446
# [PROGRAM]: INFERENCE BATCH  385  /446
# [PROGRAM]: INFERENCE BATCH  386  /446
# [PROGRAM]: INFERENCE BATCH  387  /446
# [PROGRAM]: INFERENCE BATCH  388  /446
# [PROGRAM]: INFERENCE BATCH  389  /446
# [PROGRAM]: INFERENCE BATCH  390  /446
# [PROGRAM]: INFERENCE BATCH  391  /446
# [PROGRAM]: INFERENCE BATCH  392  /446
# [PROGRAM]: INFERENCE BATCH  393  /446
# [PROGRAM]: INFERENCE BATCH  394  /446
# [PROGRAM]: INFERENCE BATCH  395  /446
# [PROGRAM]: INFERENCE BATCH  396  /446
# [PROGRAM]: INFERENCE BATCH  397  /446
# [PROGRAM]: INFERENCE BATCH  398  /446
# [PROGRAM]: INFERENCE BATCH  399  /446
# [PROGRAM]: INFERENCE BATCH  400  /446
# [PROGRAM]: INFERENCE BATCH  401  /446
# [PROGRAM]: INFERENCE BATCH  402  /446
# [PROGRAM]: INFERENCE BATCH  403  /446
# [PROGRAM]: INFERENCE BATCH  404  /446
# [PROGRAM]: INFERENCE BATCH  405  /446
# [PROGRAM]: INFERENCE BATCH  406  /446
# [PROGRAM]: INFERENCE BATCH  407  /446
# [PROGRAM]: INFERENCE BATCH  408  /446
# [PROGRAM]: INFERENCE BATCH  409  /446
# [PROGRAM]: INFERENCE BATCH  410  /446
# [PROGRAM]: INFERENCE BATCH  411  /446
# [PROGRAM]: INFERENCE BATCH  412  /446
# [PROGRAM]: INFERENCE BATCH  413  /446
# [PROGRAM]: INFERENCE BATCH  414  /446
# [PROGRAM]: INFERENCE BATCH  415  /446
# [PROGRAM]: INFERENCE BATCH  416  /446
# [PROGRAM]: INFERENCE BATCH  417  /446
# [PROGRAM]: INFERENCE BATCH  418  /446
# [PROGRAM]: INFERENCE BATCH  419  /446
# [PROGRAM]: INFERENCE BATCH  420  /446
# [PROGRAM]: INFERENCE BATCH  421  /446
# [PROGRAM]: INFERENCE BATCH  422  /446
# [PROGRAM]: INFERENCE BATCH  423  /446
# [PROGRAM]: INFERENCE BATCH  424  /446
# [PROGRAM]: INFERENCE BATCH  425  /446
# [PROGRAM]: INFERENCE BATCH  426  /446
# [PROGRAM]: INFERENCE BATCH  427  /446
# [PROGRAM]: INFERENCE BATCH  428  /446
# [PROGRAM]: INFERENCE BATCH  429  /446
# [PROGRAM]: INFERENCE BATCH  430  /446
# [PROGRAM]: INFERENCE BATCH  431  /446
# [PROGRAM]: INFERENCE BATCH  432  /446
# [PROGRAM]: INFERENCE BATCH  433  /446
# [PROGRAM]: INFERENCE BATCH  434  /446
# [PROGRAM]: INFERENCE BATCH  435  /446
# [PROGRAM]: INFERENCE BATCH  436  /446
# [PROGRAM]: INFERENCE BATCH  437  /446
# [PROGRAM]: INFERENCE BATCH  438  /446
# [PROGRAM]: INFERENCE BATCH  439  /446
# [PROGRAM]: INFERENCE BATCH  440  /446
# [PROGRAM]: INFERENCE BATCH  441  /446
# [PROGRAM]: INFERENCE BATCH  442  /446
# [PROGRAM]: INFERENCE BATCH  443  /446
# [PROGRAM]: INFERENCE BATCH  444  /446
# [PROGRAM]: INFERENCE BATCH  445  /446
# [PROGRAM]: INFERENCE BATCH  446  /446

# %%
print("[INFO]: computing metrics")
metrics_avg = score_avg(y_pred, y_test)
# Out:
# [INFO]: computing metrics
# [PROGRAM]: classifier -> BERT finetuned
# [PROGRAM]: avg precision: 0.8423171840498767
# [PROGRAM]: avg recall: 0.5113143578017819
# [PROGRAM]: avg f1-score: 0.6363457953095869
# [PROGRAM]: avg hamming loss: 0.009219478823309908
# [PROGRAM]: avg jacard score: 0.4666474778729222
